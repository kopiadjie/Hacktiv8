# %%
import pandas as pd
import numpy as np

# %%
crime_london = pd.read_csv('london_crime_by_lsoa.csv')

# %%
crime_london.head()
# Out:
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
crime_london.drop(["lsoa_code"], axis=1, inplace=True)

# %%
crime_london.head()
# Out:
#       borough               major_category               minor_category  \
# 0     Croydon                     Burglary  Burglary in Other Buildings
# 1   Greenwich  Violence Against the Person               Other violence
# 2     Bromley  Violence Against the Person               Other violence
# 3   Redbridge                     Burglary  Burglary in Other Buildings
# 4  Wandsworth                      Robbery            Personal Property
#
#    value  year  month
# 0      0  2016     11
# 1      0  2016     11
# 2      0  2015      5
# 3      0  2016      3
# 4      0  2008      6

# %%
crime_london[crime_london['borough'] == 'Sutton']
# Out:
#          borough               major_category                 minor_category  \
# 9         Sutton           Theft and Handling    Theft/Taking of Pedal Cycle
# 19        Sutton                        Drugs            Possession Of Drugs
# 79        Sutton                      Robbery              Personal Property
# 97        Sutton                     Burglary    Burglary in Other Buildings
# 101       Sutton  Violence Against the Person                   Wounding/GBH
# ...          ...                          ...                            ...
# 13490331  Sutton           Theft and Handling  Theft/Taking Of Motor Vehicle
# 13490364  Sutton  Violence Against the Person                     Harassment
# 13490380  Sutton  Violence Against the Person                 Common Assault
# 13490579  Sutton                        Drugs               Drug Trafficking
# 13490601  Sutton                     Burglary         Burglary in a Dwelling
#
#           value  year  month
# ...

# %%
years = range (2009,2014)
sutton = crime_london.loc['Sutton', years]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 2
#       1 years = range (2009,2014)
# ----> 2 sutton = crime_london.loc['Sutton', years]
#
# File p:\Apps\anaconda3\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File p:\Apps\anaconda3\lib\site-packages\pandas\core\indexing.py:1247, in _LocIndexer._getitem_tuple(self, tup)
#    1245 with suppress(IndexingError):
#    1246     tup = self._expand_ellipsis(tup)
# -> 1247     return self._getitem_lowerdim(tup)
#    1249 # no multi-index, so validate all of the indexers
# ...
